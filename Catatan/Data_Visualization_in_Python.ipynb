# %% [markdown]
# ## SETUP

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Graphic Anatomy in Python (Matplotlib)

# %% [markdown]
# <img src="https://miro.medium.com/max/419/0*4YHR28Wt4LWg77e3.png"></img>

# %% [markdown]
# **Figure**: It's basically image that shows the graphs
# **Axes**: Chart box. You can insert any chart features including axis, labels, plots, etc.

# %% [markdown]
# ## Basic Matplotlib Plot

# %%
plt.plot()
# Out:
# []

# %% [markdown]
# `plt.plot()` shows the empty figure and an axes

# %% [markdown]
# Let's we plot a simple chart using `plt.plot()`

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Matplotlib Subplot
#
# In Matplotlib, subplots allow you to create multiple plots within a single figure. This is useful when you want to display multiple graphs or visualizations side by side for comparison or to present different aspects of your data.

# %%
# fig for figure; ax for axes
fig, ax = plt.subplots()

# %% [markdown]
# `fig, ax` means that while you running the `plt.subplots`, you also create the figure and axes.

# %%
fig

# %% [markdown]
# fig basically only an image. So, if you apply the `.plot()` method onto fig, it's getting error.

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

fig.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-621839d1cb23> in <cell line: 4>()
#       2 y = [1,4,9,16,25]
#       3
# ----> 4 fig.plot(x,y)
#       5 plt.show()
#
# AttributeError: 'Figure' object has no attribute 'plot'

# %% [markdown]
# Meanwhile, `ax` is axes that is an `axes` instance so you can put on any methods to build your chart.

# %%
ax
# Out:
# <Axes: >

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

ax.plot(x,y)
fig

# %% [markdown]
# ### Multiple subplots

# %%
fig, axes = plt.subplots(ncols=2,figsize=(8,3)) #ncols,nrows,figsize=(width,height)

# %% [markdown]
# Since you define a multiple subplot, the `axes` itself is a numpy array (it's like list but based on `numpy` library)

# %%
axes #the axes consist of two elements
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
x1 = [1,2,3,4,5]
y1 = [1,4,9,16,25]

x2 = [1,2,3,4,5]
y2 = [2,4,6,8,10]

# %%
axes.plot(x1,x2)
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-9403f0594078> in <cell line: 1>()
# ----> 1 axes.plot(x1,x2)
#       2 fig
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %% [markdown]
# If we run `axes.plot(x1,x2)`, it will be getting error because it's not `<Axes:>` instance but `numpy.ndarray` instance.
#
# So, to insert a chart onto one of the axes, you have to access it by slicing the element like in list/tuple.

# %%
axes[0].plot(x1,y1)
axes[1].plot(x2,y2)
fig

# %% [markdown]
# **It's recommended to build charts step by step from defining fig and axes until you adding some features in a single cell.**

# %%
fig, axes = plt.subplots(ncols=2,figsize=(8,3))

x1 = [1,2,3,4,5]
y1 = [1,4,9,16,25]

x2 = [1,2,3,4,5]
y2 = [2,4,6,8,10]

axes[0].plot(x1,y1)
axes[1].plot(x2,y2)

plt.show()

# %% [markdown]
# ## The Features

# %% [markdown]
# ### Title

# %% [markdown]
# **Insert title onto each subplot**

# %%
fig, axes = plt.subplots(ncols=2,figsize=(8,3))

x1 = [1,2,3,4,5]
y1 = [1,4,9,16,25]

x2 = [1,2,3,4,5]
y2 = [2,4,6,8,10]

axes[0].plot(x1,y1)
axes[1].plot(x2,y2)

#--- Define Title ---
axes[0].set_title("Exponential Curve")
axes[1].set_title("Linear Curve")

plt.show()

# %% [markdown]
# **Insert title to figure**

# %%
fig, axes = plt.subplots(ncols=2,figsize=(8,4))

x1 = [1,2,3,4,5]
y1 = [1,4,9,16,25]

x2 = [1,2,3,4,5]
y2 = [2,4,6,8,10]

axes[0].plot(x1,y1)
axes[1].plot(x2,y2)

#--- Define Title to Each Subplot---
axes[0].set_title("Exponential Curve")
axes[1].set_title("Linear Curve")

#--- Define Figure's Title---
fig.suptitle("Figure Title")
fig.subplots_adjust(top=0.85) #Position setting from the suptitle

plt.show()

# %% [markdown]
# ### Axis Label

# %%
fig, axes = plt.subplots(ncols=2,figsize=(8,4))

x1 = [1,2,3,4,5]
y1 = [1,4,9,16,25]

x2 = [1,2,3,4,5]
y2 = [2,4,6,8,10]

axes[0].plot(x1,y1)
axes[1].plot(x2,y2)

axes[0].set_title("Exponential Curve")
axes[1].set_title("Linear Curve")

#Define axis label to the first subplot
axes[0].set_xlabel('X-Axis Axes 0')
axes[0].set_ylabel('Y-Axis Axes 0')

#Define axis label to the second subplot
axes[1].set_xlabel('X-Axis Axes 1')
axes[1].set_ylabel('Y-Axis Axes 1')

fig.suptitle("These are My Graphs")
fig.subplots_adjust(top=0.76)

plt.show()

# %% [markdown]
# ### Legend

# %%
fig, ax = plt.subplots()

x1 = [1,2,3,4,5]
y1 = [1,4,9,16,25]

x2 = [1,2,3,4,5]
y2 = [2,4,6,8,10]

ax.plot(x1,y1, label="exponential") #You have to set the label in every chart first
ax.plot(x2,y2, label="linear")

ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')

ax.set_title('Our Curves')

plt.legend() #Using this code to show the legend
plt.show()

# %% [markdown]
# **Change the legend position**

# %%
fig, ax = plt.subplots()

x1 = [1,2,3,4,5]
y1 = [1,4,9,16,25]

x2 = [1,2,3,4,5]
y2 = [2,4,6,8,10]

ax.plot(x1,y1, label="exponential")
ax.plot(x2,y2, label="linear")

ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')

ax.set_title('Our Curves')

plt.legend(bbox_to_anchor=(0.75,-0.15),ncol=2)

plt.show()

# %% [markdown]
# ## Data Visualization & Graphs

# %% [markdown]
# ### The Data

# %%
data = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/sleep_dat.csv')
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
data["BMI Category"].unique()
# Out:
# array(['Overweight', 'Normal', 'Obese', 'Normal Weight'], dtype=object)

# %%
data["Sleep Disorder"].unique()
# Out:
# array([nan, 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
# Take out " Weight" biar normal ga ada dua
data["BMI Category"] = data["BMI Category"].str.replace(" Weight", "")
# Ganti missing value (yang ga punya kelainan tidur) dengan kata "Normal"
data["Sleep Disorder"] = data["Sleep Disorder"].fillna("Normal")

# Cek lagi
print(data["BMI Category"].unique())
print(data["Sleep Disorder"].unique())
# Out:
# ['Overweight' 'Normal' 'Obese']
# ['Normal' 'Sleep Apnea' 'Insomnia']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %% [markdown]
# There are no missing values and the data types are suitable.

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# #### The Basic - Vertical bar chart

# %%
occupation_freq = data['Occupation'].value_counts()
occupation_freq
# Out:
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
occupation_freq.plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
data['Occupation'].value_counts().plot(kind='bar');

# %%
occupation_freq.plot(kind='bar', color=['blue','green','yellow','orange','red', 'magenta', 'navy', 'black', 'pink', 'grey', 'purple'])
# Out:
# <Axes: xlabel='Occupation'>

# %%
ax = occupation_freq.plot(kind='bar', color=['blue','green','yellow','orange','red', 'magenta', 'navy', 'black', 'pink', 'grey', 'purple'])
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '73'),
#  Text(0, 0, '71'),
#  Text(0, 0, '63'),
#  Text(0, 0, '47'),
#  Text(0, 0, '40'),
#  Text(0, 0, '37'),
#  Text(0, 0, '32'),
#  Text(0, 0, '4'),
#  Text(0, 0, '4'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1')]

# %%
ax = occupation_freq.plot(kind='bar', color=['blue','green','yellow','orange','red', 'magenta', 'navy', 'black', 'pink', 'grey', 'purple'])
ax.bar_label(ax.containers[0]);

# %% [markdown]
# ### Horizontal bar chart

# %%
axh = occupation_freq.plot(kind='barh', color=['blue','green','yellow','orange','red', 'magenta', 'navy', 'black', 'pink', 'grey', 'purple'])
axh.bar_label(axh.containers[0]);

# %% [markdown]
# ### Multi category

# %%
data.groupby(['Gender','BMI Category'])['Daily Steps'].mean().reset_index()
# Out:
#    Gender BMI Category  Daily Steps
# 0  Female       Normal  6103.846154
# 1  Female        Obese  3300.000000
# 2  Female   Overweight  7416.037736
# 3    Male       Normal  7311.594203
# 4    Male        Obese  3355.555556
# 5    Male   Overweight  5828.571429

# %% [markdown]
# **Using Pandas**

# %%
data.groupby(['Gender','BMI Category'])['Daily Steps'].mean().plot(kind='bar', color=['black', 'black', 'pink', 'black', 'black', 'black', 'black', 'black'])
# Out:
# <Axes: xlabel='Gender,BMI Category'>

# %% [markdown]
# **Using Seaborn**

# %%
daily_steps = data.groupby(['Gender','BMI Category'])['Daily Steps'].mean().reset_index()

sns.barplot(data=daily_steps, x='Gender', y='Daily Steps', orient='v', hue='BMI Category')
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200         Normal
# ...

# %%
fig,ax1 = plt.subplots(figsize=(8,8))

data['Sleep Disorder'].value_counts().plot(kind='pie', autopct='%.2f%%', ax=ax1)
plt.show()

# %% [markdown]
# We can connect the pandas visualization to matplotlib subplot using argument like `ax=ax1`. `ax1` is the axes' name that we difined at first.
#
# This will be the same for `seaborn`.

# %% [markdown]
# ### Line Chart

# %%
inflation = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/inflation_data.csv')
inflation
# Out:
#     year       amount  inflation rate
# 0   1960       100.00            0.40
# 1   1961       113.69            0.14
# 2   1962       263.08            1.31
# 3   1963       646.94            1.46
# 4   1964      1352.08            1.09
# ..   ...          ...             ...
# 59  2019  54442017.18            0.03
# 60  2020  55487861.23            0.02
# 61  2021  56353513.85            0.02
# 62  2022  58725685.04            0.04
# 63  2023  60751766.70            0.03
#
# [64 rows x 3 columns]

# %%
inflation.head(15)
# Out:
#     year     amount  inflation rate
# 0   1960     100.00            0.40
# 1   1961     113.69            0.14
# 2   1962     263.08            1.31
# 3   1963     646.94            1.46
# 4   1964    1352.08            1.09
# 5   1965    5499.76            3.07
# 6   1966   67990.95           11.36
# 7   1967  140061.36            1.06
# 8   1968  320520.69            1.29
# 9   1969  370136.94            0.15
# 10  1970  416031.92            0.12
# 11  1971  433645.70            0.04
# 12  1972  461926.94            0.07
# 13  1973  605317.92            0.31
# 14  1974  850421.63            0.40

# %% [markdown]
# **Using Pandas**

# %%
inflation.plot(kind='line',x="year",y="inflation rate")
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# **Using Seaborn**

# %%
sns.lineplot(data=inflation, x='year',y='amount')
# Out:
# <Axes: xlabel='year', ylabel='amount'>

# %%
sns.lineplot(data=inflation, x='year',y='inflation rate')
# Out:
# <Axes: xlabel='year', ylabel='inflation rate'>

# %% [markdown]
# ### Area Chart

# %%
inflation.plot(kind='area', x='year',y='amount')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### Scatter Chart

# %%
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200         Normal
# ...

# %% [markdown]
# **Using Matplotlib's Pyplot Directly**

# %%
fig, ax = plt.subplots()

ax.set_title('Heart Rate vs Daily Steps')
ax.set_xlabel('Heart Rate')
ax.set_ylabel('Daily Steps')

ax.scatter(x=data['Heart Rate'],y=data['Daily Steps'])
plt.show()

# %% [markdown]
# **Using Pandas**

# %%
fig, ax2 = plt.subplots()

ax2.set_title('Heart Rate vs Daily Steps')
ax2.set_xlabel('Heart Rate')
ax2.set_ylabel('Daily Steps')

data.plot(kind='scatter', x='Heart Rate', y='Daily Steps', ax=ax2)
plt.show()

# %% [markdown]
# **Using Seaborn**

# %%
fig, ax3 = plt.subplots()

ax.set_title('Heart Rate vs Daily Steps')
ax.set_xlabel('Heart Rate')
ax.set_ylabel('Daily Steps')

sns.scatterplot(x=data['Heart Rate'],y=data['Daily Steps'],ax=ax3)
plt.show()

# %% [markdown]
# ### Bubble Plot
#
# For convinient, bubble lot can be built by `sns.scatterplot`. We can add colors, sizes, and markers to add more information/dimensions.

# %% [markdown]
# **Colors as Additional Info**

# %%
fig, ax = plt.subplots()

ax.set_title('Heart Rate vs Daily Steps')
ax.set_xlabel('Heart Rate')
ax.set_ylabel('Daily Steps')

sns.scatterplot(data=data, x='Heart Rate',y='Daily Steps', hue='Gender', ax=ax)
plt.show()

# %% [markdown]
# **Markers as Additional Info**

# %%
fig, ax = plt.subplots()

ax.set_title('Heart Rate vs Daily Steps')
ax.set_xlabel('Heart Rate')
ax.set_ylabel('Daily Steps')

sns.scatterplot(data=data, x='Heart Rate',y='Daily Steps', style='BMI Category', ax=ax)
plt.show()

# %% [markdown]
# **Sizes as Additional Info**

# %%
fig, ax = plt.subplots()

ax.set_title('Heart Rate vs Daily Steps')
ax.set_xlabel('Heart Rate')
ax.set_ylabel('Daily Steps')

sns.scatterplot(data=data, x='Heart Rate',y='Daily Steps', size='Physical Activity Level', sizes=(10,100), ax=ax)
plt.show()

# %% [markdown]
# **Combining Hue, Style, and Size**

# %%
fig, ax = plt.subplots()

ax.set_title('Heart Rate vs Daily Steps')
ax.set_xlabel('Heart Rate')
ax.set_ylabel('Daily Steps')

sns.scatterplot(data=data, x='Heart Rate',y='Daily Steps', hue='Gender', style='BMI Category', size='Physical Activity Level', ax=ax)
plt.legend(bbox_to_anchor=(-0.2,1))
plt.show()

# %% [markdown]
# ### Box Plot

# %%
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200         Normal
# ...

# %% [markdown]
# **Using Pandas**

# %%
data['Physical Activity Level'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# **Using Seaborn - Single Box Plot**

# %%
sns.boxplot(x=data['Physical Activity Level']) #Horizontal
# Out:
# <Axes: xlabel='Physical Activity Level'>

# %%
sns.boxplot(y=data['Physical Activity Level']) #Vertical
# Out:
# <Axes: ylabel='Physical Activity Level'>

# %% [markdown]
# **Using Seaborn - Multiple Box Plot**

# %%
sns.boxplot(data=data, x='Sleep Disorder', y='Physical Activity Level')
plt.xlabel('Physical Activity Level')
# Out:
# Text(0.5, 0, 'Physical Activity Level')

# %% [markdown]
# ### Histogram

# %% [markdown]
# **Using Pandas**

# %%
data['Age'].plot(kind='hist',bins=10);

# %%
# Add label
ax = data['Age'].plot(kind='hist',bins=20)
ax.bar_label(ax.containers[0]);

# %%
import numpy as np

# See the label [0] & label limits [1]
np.histogram(data['Age'], bins=20)
# Out:
# (array([ 6, 26, 18, 30,  2, 24, 40, 15, 16,  9, 64, 14,  0, 14, 20, 17, 24,
#          2, 11, 22]),
#  array([27. , 28.6, 30.2, 31.8, 33.4, 35. , 36.6, 38.2, 39.8, 41.4, 43. ,
#         44.6, 46.2, 47.8, 49.4, 51. , 52.6, 54.2, 55.8, 57.4, 59. ]))

# %%
print(data['Age'].min())
print(data['Age'].max())
# Out:
# 27
# 59

# %%
# Add the label limits
ax = data['Age'].plot(kind='hist',bins=20)
ax.bar_label(ax.containers[0])
# Applying with 'plt.ticks()'
plt.xticks(np.histogram(data['Age'], bins=20)[1], rotation=90);

# %%
# Add line plot
ax = data['Age'].plot(kind='hist',bins=20)
# Add label
ax.bar_label(ax.containers[0])
# Add X-Ticks
plt.xticks(np.histogram(data['Age'], bins=20)[1], rotation=45)
# Appplying
ax.plot(np.histogram(data['Age'], bins=20)[1][:-1], np.histogram(data['Age'], bins=20)[0]);

# %% [markdown]
# **Using Seaborn**

# %%
sns.histplot(x=data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### Heatmap

# %% [markdown]
# We will take example of correlation. Assume that all variables can be applied Pearson correlation.

# %%
data.corr(numeric_only=True)
# Out:
#                          Person ID       Age  Sleep Duration  \
# Person ID                 1.000000  0.990516        0.296305
# Age                       0.990516  1.000000        0.344709
# Sleep Duration            0.296305  0.344709        1.000000
# Quality of Sleep          0.431612  0.473734        0.883213
# Physical Activity Level   0.149882  0.178993        0.212360
# Stress Level             -0.394287 -0.422344       -0.811023
# Heart Rate               -0.225467 -0.225606       -0.516455
# Daily Steps               0.043844  0.057973       -0.039533
#
#                          Quality of Sleep  Physical Activity Level  \
# Person ID                        0.431612                 0.149882
# Age                              0.473734                 0.178993
# Sleep Duration                   0.883213                 0.212360
# Quality of Sleep                 1.000000                 0.192896
# Physical Activity Level          0.192896                 1.000000
# ...

# %%
sns.heatmap(data.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Treemap and Choropleth
#
# To make Treemap and Choropleth (or any geochart) it's difficult by using matplotlib and seaborn, so `Plotly` or any library needed. We won't to discuss it in the class, you can see the references that provided on the last slide.
